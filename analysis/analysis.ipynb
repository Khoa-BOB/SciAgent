# %%
from pathlib import Path

data_path = Path("../data/csAI") / "cs_ai_papers.jsonl"

print("Path:", data_path.resolve())
print("Exists:", data_path.exists())
print("File size:", data_path.stat().st_size if data_path.exists() else "N/A")
# Out:
# Path: /Users/khoatran/Documents/SciAgent/data/csAI/cs_ai_papers.jsonl
# Exists: True
# File size: 386896183

# %%
import pandas as pd

df = pd.read_json(
    data_path,
    lines=True,
    nrows=1
)

df
# Out:
#          id    submitter                 authors  \
# 0  704.0047  Igor Grabec  T. Kosel and I. Grabec
#
#                                                title  \
# 0  Intelligent location of simultaneously active ...
#
#                                     comments  journal-ref  doi  report-no  \
# 0  5 pages, 5 eps figures, uses IEEEtran.cls          NaN  NaN        NaN
#
#     categories  license                                           abstract  \
# 0  cs.NE cs.AI      NaN    The intelligent acoustic emission locator is...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2009-09-29
#
#                     authors_parsed
# 0  [[Kosel, T., ], [Grabec, I., ]]

# %% [markdown]
# ## Metadata KG
